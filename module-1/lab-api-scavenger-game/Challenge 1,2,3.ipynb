# %%
# imports
from dotenv import load_dotenv
import os
import json
import requests
import pandas as pd

# KEY
load_dotenv(dotenv_path='.env')
SECRET_KEY = os.getenv("KEY")

# %% [raw]
# 1. Conseguir el token en github y comprobar que es valido
#
# $ curl -u Paulapr:SECRET_KEY https://api.github.com/user

# %%
# Challenge 1 - Fork Languages

forks = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/forks')

forks = forks.json()
print(forks)
# Out:
# [{'id': 167147514, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjcxNDc1MTQ=', 'name': 'datamad0119-1', 'full_name': 'RodMech/datamad0119-1', 'private': False, 'owner': {'login': 'RodMech', 'id': 33937164, 'node_id': 'MDQ6VXNlcjMzOTM3MTY0', 'avatar_url': 'https://avatars2.githubusercontent.com/u/33937164?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/RodMech', 'html_url': 'https://github.com/RodMech', 'followers_url': 'https://api.github.com/users/RodMech/followers', 'following_url': 'https://api.github.com/users/RodMech/following{/other_user}', 'gists_url': 'https://api.github.com/users/RodMech/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/RodMech/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/RodMech/subscriptions', 'organizations_url': 'https://api.github.com/users/RodMech/orgs', 'repos_url': 'https://api.github.com/users/RodMech/repos', 'events_url': 'https://api.github.com/users/RodMech/events{/privacy}', 'received_events_url': 'ht
# ...

# %%
language_list = list(set(forks['language']))
print (language_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6eb0ec2b0807> in <module>()
# ----> 1 language_list = list(set(forks['language']))
#       2 print (language_list)
#
# TypeError: list indices must be integers or slices, not str

# %%
#Challenge 2: Count Commits

commits = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/commits?since=2019-29-01T00:00:00Z&until=2019-5-02T23:59:59Z')

commits = commits.json()
print(commits)
# Out:
# [{'sha': 'a3bb8cebd5bd269c339092d447e2d95cd5773c47', 'node_id': 'MDY6Q29tbWl0MTY3MDA3MTYzOmEzYmI4Y2ViZDViZDI2OWMzMzkwOTJkNDQ3ZTJkOTVjZDU3NzNjNDc=', 'commit': {'author': {'name': 'Zhou Zhou', 'email': 'zhou.eye8@gmail.com', 'date': '2019-01-29T02:20:49Z'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'date': '2019-01-29T02:20:49Z'}, 'message': 'Update LICENSE', 'tree': {'sha': 'a7f6cad36388887518110899a71854779feeef3d', 'url': 'https://api.github.com/repos/ironhack-datalabs/datamad0119/git/trees/a7f6cad36388887518110899a71854779feeef3d'}, 'url': 'https://api.github.com/repos/ironhack-datalabs/datamad0119/git/commits/a3bb8cebd5bd269c339092d447e2d95cd5773c47', 'comment_count': 0, 'verification': {'verified': True, 'reason': 'valid', 'signature': '-----BEGIN PGP SIGNATURE-----\n\nwsBcBAABCAAQBQJcT7iBCRBK7hj4Ov3rIwAAdHIIAIvktbgSfsOBzAUARDBpUR0d\nktQKS46JXLFYSe9q6LMrvZEl71ByYCUifFI6OO/VViApHeUzkVKCYpuOScmGAkaH\nvn/hm9tOngh6zG8RcGlAIEPw22/3bSQsXji8pMJZEXZV2257nPv03AougQIiH
# ...

# %%
number_commits= len(commits)

number_commits # 1 solo commit en la ultima semana
# Out:
# 1

# %%
commits18 = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')

commits18 = commits18.json()

number_commits18= len(commits18)

number_commits18 # En el repo de 2018 hubo un total de 30 commits
# Out:
# 30

# %%
#Challenge 3: Hidden Cold Joke

scavengers = requests.get('https://api.github.com/search/code?q=repo:ironhack-datalabs/scavenger+filename:scavengerhunt')

labscab = scavengers.json()

labscab
# Out:
# {'incomplete_results': False,
#  'items': [{'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#    'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'repository': {'archive_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/{archive_format}{/ref}',
#     'assignees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}',
#     'blobs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}',
#     'branches_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}',
#     'collaborators_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}',
# ...

# %%
path=list(map(lambda d: d['path'], url))
names=list(map(lambda d: d['name'], url))
path
name
name_paths=dict(zip(name,path))
name_paths
# Out:
# {'.0001.scavengerhunt': '98750/.0001.scavengerhunt',
#  '.0002.scavengerhunt': '88596/.0002.scavengerhunt',
#  '.0003.scavengerhunt': '60224/.0003.scavengerhunt',
#  '.0004.scavengerhunt': '68848/.0004.scavengerhunt',
#  '.0005.scavengerhunt': '44639/.0005.scavengerhunt',
#  '.0006.scavengerhunt': '15024/.0006.scavengerhunt',
#  '.0007.scavengerhunt': '17020/.0007.scavengerhunt',
#  '.0008.scavengerhunt': '15534/.0008.scavengerhunt',
#  '.0009.scavengerhunt': '97881/.0009.scavengerhunt',
#  '.0010.scavengerhunt': '47830/.0010.scavengerhunt',
#  '.0011.scavengerhunt': '50896/.0011.scavengerhunt',
#  '.0012.scavengerhunt': '15534/.0012.scavengerhunt',
#  '.0013.scavengerhunt': '89338/.0013.scavengerhunt',
#  '.0014.scavengerhunt': '49418/.0014.scavengerhunt',
#  '.0015.scavengerhunt': '91701/.0015.scavengerhunt',
#  '.0016.scavengerhunt': '47222/.0016.scavengerhunt',
#  '.0017.scavengerhunt': '70985/.0017.scavengerhunt',
#  '.0018.scavengerhunt': '45525/.0018.scavengerhunt',
# ...

# %%
words = list(map(lambda paths:'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/{}'.format(paths),path))
    
words
# Out:
# ['https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/49418/.0014.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0008.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/70985/.0017.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0012.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/17020/.0007.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/91701/.0015.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/30351/.0021.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/40303/.0022.scavengerhunt',
# ...

# %% [markdown]
# # Las direcciones funcionan abriendolas a mano en el servidor. No consigo hacerlo de otra manera:
#
# LA FRASE ES: "In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare  data."

# %%
# abrir un archivo --> NO FUNCIONA

with open('https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt') as f:
    data = f.read()
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-120-b047e15281a0> in <module>()
#       1 # abrir un archivo
#       2
# ----> 3 with open('https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt') as f:
#       4     data = f.read()
#       5     print(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt'
