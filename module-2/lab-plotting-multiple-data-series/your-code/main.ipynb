# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data_itemtype = data[["RetailSales", "RetailTransfers", "WarehouseSales","ItemType"]].groupby(["ItemType"]).agg("count")
data_itemtype.plot.bar(figsize=(12,6))

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['sales_mix']= data['RetailSales']+ data['RetailTransfers']+ data['WarehouseSales']
data1 = data.groupby(["Supplier"]).agg({'sales_mix':"sum"})
data1 = data1.sort_values('sales_mix',ascending = False).head(10)

data1.plot.barh(color='g')

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
#unir columnas year y month

data2 = data.groupby(['Year','Month']).agg({"mean"}).reset_index()
data2.drop(columns=['sales_mix'],inplace = True)
data2.sort_values(by=['Year','Month'], inplace=True)

data2.plot(y=['RetailSales','RetailTransfers','WarehouseSales'],figsize=(12,6))

plt.title('Average sales over time')
plt.xlabel('Meses')
plt.ylabel('avg sales')
plt.xticks(np.arange(12), ('abr', 'may', 'jun','ago', 'sep', 'oct', 'nov','dic', 'ene', 'feb'))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1d8b025a20>,
#   <matplotlib.axis.XTick at 0x7f1d8b025358>,
#   <matplotlib.axis.XTick at 0x7f1d8afdb1d0>,
#   <matplotlib.axis.XTick at 0x7f1d8b05f550>,
#   <matplotlib.axis.XTick at 0x7f1d8b055898>,
#   <matplotlib.axis.XTick at 0x7f1d8b055da0>,
#   <matplotlib.axis.XTick at 0x7f1d8b0bd5f8>,
#   <matplotlib.axis.XTick at 0x7f1d8b025048>,
#   <matplotlib.axis.XTick at 0x7f1d8b0ccd68>,
#   <matplotlib.axis.XTick at 0x7f1d8b0cc748>,
#   <matplotlib.axis.XTick at 0x7f1d8b0cc710>,
#   <matplotlib.axis.XTick at 0x7f1d8b0964e0>],
#  <a list of 10 Text xticklabel objects>)

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data2.plot.bar(y=['RetailSales','RetailTransfers','WarehouseSales'],figsize=(12,6))
plt.title('Average sales over time')
plt.xlabel('Meses')
plt.ylabel('avg sales')
plt.xticks(np.arange(12), ('abr', 'may', 'jun','ago', 'sep', 'oct', 'nov','dic', 'ene', 'feb'))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1d8ab0b080>,
#   <matplotlib.axis.XTick at 0x7f1d8ab0a940>,
#   <matplotlib.axis.XTick at 0x7f1d8aa26c50>,
#   <matplotlib.axis.XTick at 0x7f1d8aa30240>,
#   <matplotlib.axis.XTick at 0x7f1d8aa306d8>,
#   <matplotlib.axis.XTick at 0x7f1d8aa26dd8>,
#   <matplotlib.axis.XTick at 0x7f1d8aa30c88>,
#   <matplotlib.axis.XTick at 0x7f1d8ab0a6a0>,
#   <matplotlib.axis.XTick at 0x7f1d8aa48400>,
#   <matplotlib.axis.XTick at 0x7f1d8aa406d8>,
#   <matplotlib.axis.XTick at 0x7f1d8aa40c88>,
#   <matplotlib.axis.XTick at 0x7f1d8aa486a0>],
#  <a list of 10 Text xticklabel objects>)

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.set(rc={'figure.figsize':(12,6)})

g = sns.lmplot(x='RetailSales', y='RetailTransfers', hue="ItemType", data=data)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
#data_numeric = data['Year','Month','ItemCode','RetailSales','RetailTransfers','WarehouseSales']

g = sns.pairplot(data, hue="ItemType")
