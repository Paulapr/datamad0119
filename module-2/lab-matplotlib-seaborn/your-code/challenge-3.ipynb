# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['float64','int64']).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(include=['object']).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here

titanic['Age'].hist(bins=70)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.subplot(1,3,1)
titanic['Age'].hist(bins=10)
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
'''
Hay que elegir los contenedores o intervalos del histograma de manera que pueda observarse
zonas con mayor concentracion de datos. En el caso anterior la mejor opción es la intermedia, la de 20.
'''
# Out:
# '\nHay que elegir los contenedores o intervalos del histograma de manera que pueda observarse\nzonas con mayor concentracion de datos. En el caso anterior la mejor opción es la intermedia, la de 20.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

titanic['Gender'].value_counts().plot.bar()

# %%
# your code here- 2nd way

ax = sns.countplot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

ax = sns.countplot(x="Pclass", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here

sns.set(rc={'figure.figsize':(4,6)})
ax = sns.boxplot(y="Age", data=titanic)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
'''
El boxplot nos dice que los datos tienen una distribución aproximadamente normal, la linea en el centro de la caja
alrededor de 29 años sería la mediana, que aproximadamente coincide con la media. El cuartil 25 está en torno a 21
y el cuartil 75 entorno a 39, entre estas edades estaría el 50% de la muestra. Por encima de los 60 años se 
considerarían valores atípicos.
'''
# Out:
# '\nEl boxplot nos dice que los datos tienen una distribución aproximadamente normal, la linea en el centro de la caja\nalrededor de 29 años sería la mediana, que aproximadamente coincide con la media. El cuartil 25 está en torno a 21\ny el cuartil 75 entorno a 39, entre estas edades estaría el 50% de la muestra. Por encima de los 60 años se \nconsiderarían valores atípicos.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

sns.set(rc={'figure.figsize':(12,6)})
sns.distplot(titanic['Age'], hist=True, kde=True, 
             bins=int(180/5), color = 'black', 
             hist_kws={'edgecolor':'red'},
             kde_kws={'linewidth': 2})

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
'''
Como ya se veía en el boxplot, tiene una distribución aproximadamente normal.
'''
# Out:
# '\nComo ya se veía en el boxplot, tiene una distribución aproximadamente normal.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.jointplot(x='Age',y='Fare',data=titanic)

# %%
# your code-2nd way
age_fair = titanic[['Age', 'Fare']].copy()
titanic['Age'].astype('int64')
titanic['Fare'].astype('int64')

age_fair = titanic.groupby(['Age']).agg({'Fare':"mean"})
age_fair = age_fair.sort_values(by=['Age'])


plt.scatter(titanic['Age'],titanic['Fare'])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here

sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
'''
SibSp con Parch, que presentan los colores mas claros. También los supervivientes y Fare, sobrevivieron mas de
primera clase.
'''

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

sns.boxplot(x='Pclass',y='Age',data=titanic,palette='Set2')

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col='Gender')
g = g.map(plt.hist, "Age")
